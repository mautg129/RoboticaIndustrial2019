# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("osv_acumulado_2013-2019.xlsx", skiprows = 3, skipfooter = 2)
data
# Out:
#                    MES  Pruebas aplicadas  Conductores retenidos  \
# 0   Noviembre  (15-30)               6659                    142
# 1            Diciembre              12332                    220
# 2          Enero  2014              16944                    258
# 3              Febrero              15850                    343
# 4                Marzo              16123                    380
# 5                Abril              15714                    284
# 6                 Mayo              14774                    287
# 7                Junio              12704                    288
# 8                Julio              15343                    326
# 9               Agosto              18762                    401
# 10          Septiembre              11699                    264
# 11             Octubre              16407                    398
# 12           Noviembre              16281                    331
# ...

# %%
# !ls
# Out:
# 0x01_LEGO.ipynb              osv_acumulado_2013-2019.xlsx

# %%
data.sum()
# Out:
# MES                          Noviembre  (15-30)DiciembreEnero  2014FebreroM...
# Pruebas aplicadas                                                      2113245
# Conductores retenidos                                                    24840
# Sanción económica                                                        15214
# Total pruebas positivas                                                  40054
# %\npositivas/a plicadas      3.02%2.41%2.17%3.05%3.68%2.73%3.18%3.46%3.22%3...
# Días  con Operativo                                                       1590
# Promedio diario positivas                                              1693.72
# dtype: object

# %%
data.mean()
# Out:
# Pruebas aplicadas            33019.453125
# Conductores retenidos          388.125000
# Sanción económica              237.718750
# Total pruebas positivas        625.843750
# Días  con Operativo             24.843750
# Promedio diario positivas       26.464375
# dtype: float64

# %%
data.describe()
# Out:
#        Pruebas aplicadas  Conductores retenidos  Sanción económica  \
# count          64.000000              64.000000          64.000000
# mean        33019.453125             388.125000         237.718750
# std         25537.965370             122.652367          77.747754
# min          6659.000000             142.000000          59.000000
# 25%         17619.000000             323.750000         197.500000
# 50%         29066.000000             376.000000         230.000000
# 75%         38542.750000             429.750000         275.500000
# max        151658.000000             907.000000         513.000000
#
#        Total pruebas positivas  Días  con Operativo  Promedio diario positivas
# count                 64.00000            64.000000                  64.000000
# mean                 625.84375            24.843750                  26.464375
# std                  196.03751             6.735876                   8.762802
# ...

# %%
data.plot()

# %%
pd.read_csv("https://raw.githubusercontent.com/RoboticaIndustrial/Robotica2_2019A/master/osv_acumulado_2013-2019.c
# Out:
#   File "<ipython-input-26-6a8c217d3785>", line 1
#     pd.read_csv("https://raw.githubusercontent.com/RoboticaIndustrial/Robotica2_2019A/master/osv_acumulado_2013-2019.c
#                                                                                                                       ^
# SyntaxError: EOL while scanning string literal
